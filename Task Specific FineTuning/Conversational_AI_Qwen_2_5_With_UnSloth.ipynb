# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "trl<0.9.0" xformers

# %%
import unsloth
from unsloth import FastLanguageModel
import torch
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
max_seq_length = 4096
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Qwen2.5-3B-Instruct-bnb-4bit",
    max_seq_length=max_seq_length,
    dtype=None,
    load_in_4bit=True,
)
# Out:
# ==((====))==  Unsloth 2025.9.6: Fast Qwen2 patching. Transformers: 4.55.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.05G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/271 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,  # Standard rank for conversation patterns
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
    use_rslora=False,
)
# Out:
# Unsloth 2025.9.6 patched 36 layers with 36 QKV layers, 36 O layers and 36 MLP layers.

# %%
from datasets import load_dataset
dataset = load_dataset("bitext/Bitext-customer-support-llm-chatbot-training-dataset", split="train[:3000]")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# Bitext_Sample_Customer_Support_Training_(…):   0%|          | 0.00/19.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/26872 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['flags', 'instruction', 'category', 'intent', 'response'],
#     num_rows: 3000
# })

# %%
def format_customer_support(examples):
    """Format examples for customer support conversation task"""
    texts = []

    for i in range(len(examples["instruction"])):
        customer_query = examples["instruction"][i]
        support_response = examples["response"][i]

        # Create customer support conversation format
        messages = [
            {"role": "system", "content": "You are a helpful customer support assistant. Provide accurate, friendly, and professional assistance to customers. Be empathetic and solution-focused."},
            {"role": "user", "content": customer_query},
            {"role": "assistant", "content": support_response}
        ]

        # Apply Qwen2.5 chat template
        text = tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=False,
        )

        texts.append(text)

    return {"text": texts}

# %%
formatted_dataset = dataset.map(
    format_customer_support,
    batched=True,
    remove_columns=dataset.column_names,
    desc="Formatting for customer support conversations"
)
# Out:
# Formatting for customer support conversations:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    per_device_train_batch_size=2,
    gradient_accumulation_steps=4,  # Effective batch size: 8
    warmup_steps=10,
    max_steps=120,  # Sufficient for conversation patterns
    learning_rate=2e-4,
    fp16=not torch.cuda.is_bf16_supported(),
    bf16=torch.cuda.is_bf16_supported(),
    logging_steps=5,
    optim="adamw_8bit",
    weight_decay=0.01,
    lr_scheduler_type="cosine",
    seed=3407,
    output_dir="qwen25_customer_support",
    save_strategy="no",
)

# %%
from trl import SFTTrainer
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=formatted_dataset,
    args=training_args,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    packing=False,  # Preserve conversation structure
)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 3,000 | Num Epochs = 1 | Total steps = 120
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 29,933,568 of 3,115,872,256 (0.96% trained)
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: abeshith (abeshith-dr-m-g-r-educational-and-research-institute) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/wandb/run-20250918_105020-ivdtw50g</code>
# Syncing run <strong><a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/ivdtw50g' target="_blank">olive-sun-37</a></strong> to <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface' target="_blank">https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface</a>
#  View run at <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/ivdtw50g' target="_blank">https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/ivdtw50g</a>
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='120' max='120' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [120/120 06:08, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>3.277900</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.981300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.257700</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.031500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.873000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.727200</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.693900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.658700</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.640300</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.583200</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.612000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.568200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.559100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.528300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.565100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.557500</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.542000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.549900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.503800</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.498800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.522700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.486900</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.557900</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.562800</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=120, training_loss=0.8058204889297486, metrics={'train_runtime': 402.2538, 'train_samples_per_second': 2.387, 'train_steps_per_second': 0.298, 'total_flos': 3472440829820928.0, 'train_loss': 0.8058204889297486, 'epoch': 0.32})

# %%
model.save_pretrained("qwen25_support_agent")
tokenizer.save_pretrained("qwen25_support_agent")
# Out:
# ('qwen25_support_agent/tokenizer_config.json',
#  'qwen25_support_agent/special_tokens_map.json',
#  'qwen25_support_agent/chat_template.jinja',
#  'qwen25_support_agent/vocab.json',
#  'qwen25_support_agent/merges.txt',
#  'qwen25_support_agent/added_tokens.json',
#  'qwen25_support_agent/tokenizer.json')

# %%
FastLanguageModel.for_inference(model)

# %%
def customer_support_chat(query, context="general", max_tokens=400):
    """Handle customer support conversation"""

    system_prompts = {
        "general": "You are a helpful customer support assistant. Provide accurate, friendly, and professional assistance to customers. Be empathetic and solution-focused.",
        "billing": "You are a billing support specialist. Help customers with payment issues, invoices, refunds, and subscription management. Be clear about policies and next steps.",
        "technical": "You are a technical support expert. Help customers troubleshoot issues, provide step-by-step solutions, and escalate complex problems when needed.",
        "sales": "You are a sales support representative. Help customers with product information, pricing, comparisons, and purchase decisions. Be helpful but not pushy.",
        "returns": "You are a returns and exchange specialist. Help customers with return policies, refund processes, and product exchanges. Be understanding and efficient."
    }

    messages = [
        {"role": "system", "content": system_prompts.get(context, system_prompts["general"])},
        {"role": "user", "content": query}
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    inputs = tokenizer([text], return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_tokens,
            temperature=0.7,  # Balanced for friendly but consistent responses
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
        )

    # Extract generated tokens and decode
    generated_tokens = outputs[0][len(inputs['input_ids'][0]):]
    response = tokenizer.decode(generated_tokens, skip_special_tokens=True)

    return response.strip()

# %%
general_queries = [
    "Hi, I'm having trouble logging into my account. Can you help me?",
    "What are your business hours?",
    "I need to speak with a manager about my recent experience.",
    "Can you explain your return policy?",
    "I'm a new customer and need help getting started."
]

print("🛟 GENERAL CUSTOMER SUPPORT:")
for i, query in enumerate(general_queries, 1):
    print(f"\n👤 Customer {i}: {query}")
    response = customer_support_chat(query, "general", 300)
    print(f"🤖 Support Agent: {response}")
    print("-" * 60)
# Out:
# 🛟 GENERAL CUSTOMER SUPPORT:
#
# 👤 Customer 1: Hi, I'm having trouble logging into my account. Can you help me?
# 🤖 Support Agent: I apologize for the inconvenience you're experiencing while trying to log in to your account. To assist you further, could you please provide me with your login credentials or any error messages you may be encountering? This will help me identify the issue and provide you with the appropriate solution.
# ------------------------------------------------------------
#
# 👤 Customer 2: What are your business hours?
# 🤖 Support Agent: Our business hours are Monday through Friday from 9 AM to 5 PM Eastern Time. We're closed on weekends and holidays.
# ------------------------------------------------------------
#
# 👤 Customer 3: I need to speak with a manager about my recent experience.
# 🤖 Support Agent: I've been informed that you would like to speak with a manager regarding your recent experience. I apologize for any inconvenience this may have caused you. To assist you further, could you please provide more details about the issue or concern you have? This will help me ensure that we address your concerns appropriately and find a satisfactory solution for you.
# ------------------------------------------------------------
#
# 👤 Customer 4: Can you explain your return policy?
# 🤖 Support Agent: Sure! Our return policy is as follows: You have the option to return any product within 30 days of purchase for a full refund or exchange. To initiate a return, please contact our customer support team at [Customer Support Phone Number] or through our Live Chat on our website. We appreciate your understanding and hope this helps with your decision-making process.
# ------------------------------------------------------------
#
# 👤 Customer 5: I'm a new customer and need help getting started.
# 🤖 Support Agent: Sure! I can guide you through the process of getting started as a new customer. Let's break it down step by step:
#
# 1. **Sign Up**: Visit our website and navigate to the "Sign Up" or "Register" section. Fill out the necessary information such as your name, email address, and any other required details.
# 2. **Create Account**: Once you have completed the sign-up process, you will be prompted to create an account. Please provide your preferred username and password for easy access in the future.
# 3. **Personal Information**: You may also be asked to add some personal information such as your address, phone number, and shipping preferences. Make sure to fill these out accurately to ensure smooth delivery.
# 4. **Payment Method**: Our system supports various payment options, including credit cards, debit cards, and online banking. Choose the one that suits you best and enter the relevant information.
# 5. **Review and Confirm**: Before finalizing your purchase, review all the details you have entered and confirm that everything is correct. If you encounter any issues or have questions, don't hesitate to reach out to our customer support team.
#
# If you have any further questions or require additional assistance, feel free to ask. We're here to help you every step of the way.
# ------------------------------------------------------------

# %%
billing_queries = [
    "I was charged twice for my subscription this month. Can you help me get a refund?",
    "My payment method was declined but I know I have funds. What should I do?",
    "I want to cancel my subscription. How do I do that?",
    "Can you explain the charges on my last invoice?",
    "I need to update my billing address."
]

print("\n💳 BILLING SUPPORT:")
for i, query in enumerate(billing_queries, 1):
    print(f"\n👤 Customer {i}: {query}")
    response = customer_support_chat(query, "billing", 350)
    print(f"🤖 Billing Support: {response}")
    print("-" * 60)
# Out:
# 💳 BILLING SUPPORT:
#
# 👤 Customer 1: I was charged twice for my subscription this month. Can you help me get a refund?
# 🤖 Billing Support: I apologize for the inconvenience caused by the double charge for your subscription. To resolve this issue, I recommend reaching out to our customer support team for assistance. They will be able to investigate the situation and process the necessary refund for you. Please provide them with your order details and any relevant information so they can assist you promptly.
# ------------------------------------------------------------
#
# 👤 Customer 2: My payment method was declined but I know I have funds. What should I do?
# 🤖 Billing Support: I'm sorry to hear that your payment method was declined despite having the funds available. To resolve this issue, please follow these steps:
#
# 1. Check Your Account: Log in to your account on our website and review your payment history. This will help you identify any errors or discrepancies.
# 2. Contact Support: Reach out to our customer support team for further assistance. They can guide you through the process of resolving the declined payment and ensure that your funds are properly credited to your account.
# 3. Provide Necessary Information: When speaking with customer support, kindly provide them with the details of your payment method, including the card number, expiration date, and CVV code. This information will help them troubleshoot the problem and take appropriate actions.
# 4. Follow Up: Once you've contacted customer support, make sure to follow up regularly to ensure that your payment is processed successfully. If you encounter any further difficulties, don't hesitate to reach out again.
#
# We understand that financial challenges can be frustrating, and we are here to assist you in resolving this matter promptly. Your satisfaction is our top priority, and we appreciate your patience as we work together to find a solution.
# ------------------------------------------------------------
#
# 👤 Customer 3: I want to cancel my subscription. How do I do that?
# 🤖 Billing Support: We understand that you would like to cancel your subscription. To cancel your subscription, please follow these steps:
#
# 1. Log in to your account on our website.
# 2. Navigate to the "Account Settings" or "Profile" section.
# 3. Look for the option labeled "Manage Subscription" or "Cancel Subscription."
# 4. Click on the relevant link and confirm the cancellation.
#
# If you encounter any difficulties or have further questions, our dedicated support team is available to assist you. You can reach us during business hours by calling [Customer Support Phone Number] or using the Live Chat feature on our website at [Website URL]. We appreciate your understanding and hope to resolve this matter promptly for you.
# ------------------------------------------------------------
#
# 👤 Customer 4: Can you explain the charges on my last invoice?
# 🤖 Billing Support: I'm here to help! To provide you with a detailed breakdown of the charges on your last invoice, I'll need access to your account information and the specific details of your purchase. This way, I can accurately explain each charge and address any concerns you may have. Please feel free to share the necessary information with me, and I'll do my best to assist you.
# ------------------------------------------------------------
#
# 👤 Customer 5: I need to update my billing address.
# 🤖 Billing Support: We're here to assist you in updating your billing address. To make the necessary changes, please provide us with your current address and the new one you would like to update it to. Our team will promptly process the request and ensure that your information is updated accurately.
# ------------------------------------------------------------

# %%
technical_queries = [
    "The app keeps crashing when I try to upload files. Can you help?",
    "I'm getting an error message that says 'Connection timeout'. What does this mean?",
    "How do I reset my password? The reset email isn't coming through.",
    "The website is loading very slowly on my computer. Is there a problem?",
    "I can't find the feature you mentioned in the tutorial. Where is it located?"
]

print("\n🔧 TECHNICAL SUPPORT:")
for i, query in enumerate(technical_queries, 1):
    print(f"\n👤 Customer {i}: {query}")
    response = customer_support_chat(query, "technical", 400)
    print(f"🤖 Tech Support: {response}")
    print("-" * 60)
# Out:
# 🔧 TECHNICAL SUPPORT:
#
# 👤 Customer 1: The app keeps crashing when I try to upload files. Can you help?
# 🤖 Tech Support: I'm sorry to hear that the app is crashing while trying to upload files. To better assist you, could you please provide more information about the issue? Specifically, what do you see on the screen when the app crashes? Are there any error messages or specific steps that you can reproduce? This will help us identify the root cause of the problem and provide the most effective solution.
# ------------------------------------------------------------
#
# 👤 Customer 2: I'm getting an error message that says 'Connection timeout'. What does this mean?
# 🤖 Tech Support: The error message "Connection timeout" indicates that the system is unable to establish a connection with the required service or server within the specified time frame. This could be due to various reasons such as network connectivity issues, firewall settings, or server downtime. To resolve this issue, you can try the following steps:
#
# 1. Check your internet connection: Ensure that your device is connected to the internet and that the connection is stable.
# 2. Restart your device: Sometimes, restarting your device can help clear any temporary issues that may be causing the connection timeout.
# 3. Clear browser cache and cookies: Clearing your browser's cache and cookies can sometimes resolve connection timeouts.
# 4. Update your device drivers: Make sure that your device drivers are up to date, as outdated drivers may cause connectivity issues.
# 5. Contact your internet service provider: If the problem persists, it might be related to your internet service provider. Reach out to them for assistance.
#
# If none of these steps resolve the issue, please provide more details about the error message and the specific service or application you are trying to access. Our team will do our best to assist you further.
# ------------------------------------------------------------
#
# 👤 Customer 3: How do I reset my password? The reset email isn't coming through.
# 🤖 Tech Support: I'm sorry to hear that you're having trouble receiving the reset email for your password. Here's what you can do:
#
# 1. Check Your Spam Folder: Sometimes, emails can end up in the spam folder. Make sure to check your spam folder or junk mail as well.
#
# 2. Verify Your Email Address: Double-check that the email address associated with your account is correct. If it's not, update it in your account settings.
#
# 3. Contact Support: If you've already checked all the above steps and still haven't received the reset email, please reach out to our customer support team. They will be able to assist you further and help resolve this issue promptly.
# ------------------------------------------------------------
#
# 👤 Customer 4: The website is loading very slowly on my computer. Is there a problem?
# 🤖 Tech Support: I'm sorry to hear that you're experiencing slow website loading times on your computer. There could be several reasons for this issue. Here are some steps you can take to troubleshoot and potentially resolve the problem:
#
# 1. Clear Cache: Clearing your browser's cache can help improve website loading speed. You can do this by going to the "Settings" or "Preferences" section of your browser and selecting the option to clear cache and cookies.
#
# 2. Check Your Internet Connection: Make sure that your internet connection is stable and fast. If you're using a Wi-Fi connection, try switching to a different network or restarting your router. If you're using a mobile data plan, consider switching to a different network or waiting until you have a better signal.
#
# 3. Update Your Browser: Outdated browsers can slow down website loading times. Make sure you have the latest version of your browser installed. You can check for updates by going to the "Help" or "About" section of your browser.
#
# 4. Disable Browser Extensions: Some browser extensions can slow down website loading times. Try disabling any extensions and see if the issue persists.
#
# 5. Use a Different Device: If possible, try accessing the website from a different device, such as a tablet or smartphone. This can help determine if the problem is specific to your computer.
#
# If none of these steps resolve the issue, it may be necessary to contact customer support for further assistance. They may be able to identify any server-side issues or provide additional troubleshooting guidance.
# ------------------------------------------------------------
#
# 👤 Customer 5: I can't find the feature you mentioned in the tutorial. Where is it located?
# 🤖 Tech Support: We apologize for any confusion regarding the feature you're looking for. To assist you better, could you please provide more details about the specific feature you're trying to locate? This will help us identify its correct location and guide you through the necessary steps to access it.
# ------------------------------------------------------------

# %%
sales_queries = [
    "What's the difference between your Basic and Premium plans?",
    "Do you offer any discounts for students or nonprofits?",
    "I'm interested in your product but need to know if it integrates with Salesforce.",
    "What's included in the free trial?",
    "Can I upgrade my plan in the middle of my billing cycle?"
]

print("\n🛒 SALES SUPPORT:")
for i, query in enumerate(sales_queries, 1):
    print(f"\n👤 Customer {i}: {query}")
    response = customer_support_chat(query, "sales", 350)
    print(f"🤖 Sales Support: {response}")
    print("-" * 60)
# Out:
# 🛒 SALES SUPPORT:
#
# 👤 Customer 1: What's the difference between your Basic and Premium plans?
# 🤖 Sales Support: Our Basic plan offers a limited set of features and benefits, while our Premium plan includes additional features and benefits. The specific differences depend on the type of service you're using. For example, in the context of our product, the Basic plan may include basic features such as access to the platform, while the Premium plan may include advanced features like priority customer support and extended service hours. We recommend contacting our customer support team for more detailed information about the differences between the two plans.
# ------------------------------------------------------------
#
# 👤 Customer 2: Do you offer any discounts for students or nonprofits?
# 🤖 Sales Support: We do offer discounts for students and nonprofits! We believe in providing value to everyone, so we've created special offers just for you. To take advantage of these discounts, please provide us with your student ID or nonprofit organization details during the checkout process. This way, you can enjoy exclusive savings on our products and services.
# ------------------------------------------------------------
#
# 👤 Customer 3: I'm interested in your product but need to know if it integrates with Salesforce.
# 🤖 Sales Support: We understand that you're interested in our product and would like to know if it integrates with Salesforce. To provide you with the necessary information, we recommend checking our official documentation or contacting our customer support team for further assistance. They will be able to guide you through the integration process and answer any questions you may have.
# ------------------------------------------------------------
#
# 👤 Customer 4: What's included in the free trial?
# 🤖 Sales Support: We're happy to provide you with an overview of what's included in our free trial. Our free trial offers you the opportunity to experience our product firsthand without any financial commitment. During the trial period, you'll have access to all the features and functionalities that our product provides. This allows you to evaluate whether the product meets your needs and expectations before making a decision to purchase. We hope this information helps you make an informed choice!
# ------------------------------------------------------------
#
# 👤 Customer 5: Can I upgrade my plan in the middle of my billing cycle?
# 🤖 Sales Support: I'm happy to help! You can upgrade your plan in the middle of your billing cycle. Simply log in to your account and navigate to the "Upgrade" section. From there, you'll be able to select the desired plan and make the necessary changes. If you have any further questions or need assistance, feel free to reach out to our customer support team.
# ------------------------------------------------------------

# %%
returns_queries = [
    "I received the wrong item in my order. How can I exchange it?",
    "This product doesn't work as advertised. I'd like to return it.",
    "What's your return policy for items bought on sale?",
    "I need to return something but I threw away the packaging. Is that okay?",
    "How long do I have to return an item?"
]

print("\n📦 RETURNS & EXCHANGES:")
for i, query in enumerate(returns_queries, 1):
    print(f"\n👤 Customer {i}: {query}")
    response = customer_support_chat(query, "returns", 300)
    print(f"🤖 Returns Specialist: {response}")
    print("-" * 60)
# Out:
# 📦 RETURNS & EXCHANGES:
#
# 👤 Customer 1: I received the wrong item in my order. How can I exchange it?
# 🤖 Returns Specialist: We understand that you have received the wrong item in your order, and we apologize for any inconvenience this may have caused. To facilitate an exchange, please reach out to our customer support team. They will guide you through the process and ensure that your request is handled promptly and efficiently. Thank you for choosing us, and we appreciate your patience and understanding.
# ------------------------------------------------------------
#
# 👤 Customer 2: This product doesn't work as advertised. I'd like to return it.
# 🤖 Returns Specialist: We appreciate your feedback and the need for us to assist you with the return process for this product that doesn't meet your expectations. To ensure a smooth experience, please follow these steps:
#
# 1. Contact our customer support team during business hours (X:XX - X:XX) at {{Customer Support Phone Number}} or use the Live Chat feature on our website at {{Website URL}}.
# 2. Let them know about the specific issue you encountered with the product and provide the necessary details such as order number, purchase date, and any relevant documentation.
# 3. The customer support team will guide you through the return process and provide instructions on how to proceed with the refund or exchange.
# 4. Follow the instructions provided by the customer support team to complete the return process.
#
# Remember that we value your satisfaction and are committed to resolving any issues you may encounter. If you have any further questions or concerns, please don't hesitate to reach out to us.
# ------------------------------------------------------------
#
# 👤 Customer 3: What's your return policy for items bought on sale?
# 🤖 Returns Specialist: Our return policy for items purchased during a sale is as follows: If you're unsatisfied with your purchase, you have the option to return it within 30 days of the purchase date. To initiate the return process, please contact our customer service team, who will guide you through the necessary steps and provide you with any additional information or support needed.
# ------------------------------------------------------------
#
# 👤 Customer 4: I need to return something but I threw away the packaging. Is that okay?
# 🤖 Returns Specialist: We understand that sometimes unforeseen circumstances can occur, and we want to make sure you have all the necessary information to proceed with your return. If you've accidentally thrown away the packaging, please reach out to our customer service team, and they will guide you through the process. They may ask for additional details or steps to ensure your return is processed smoothly. Rest assured, we're here to assist you every step of the way.
# ------------------------------------------------------------
#
# 👤 Customer 5: How long do I have to return an item?
# 🤖 Returns Specialist: You have 30 days from the date of purchase to return your item. This is to ensure that you have ample time to consider your decision and make any necessary adjustments. If you need more time, please reach out to our customer support team for further assistance.
# ------------------------------------------------------------

# %%
complex_queries = [
    "I've been trying to use your service for a week but keep running into problems. First, my account wasn't activated properly, then I couldn't access the main features, and now I'm getting billed for something I never signed up for. This is very frustrating and I need someone to help me sort this out completely.",

    "I'm a business owner looking to switch from your competitor. I need to know: 1) Can you migrate our data? 2) What's the onboarding process like? 3) Do you provide training for my team? 4) What kind of support do we get after implementation?",

    "I bought your premium subscription last month, but I'm not satisfied with the performance. The app is slow, some features don't work, and customer service hasn't been helpful. I want either a full refund or a significant discount, plus assurance that these issues will be fixed."
]

print("\n🔥 COMPLEX CUSTOMER ISSUES:")
for i, query in enumerate(complex_queries, 1):
    print(f"\n👤 Frustrated Customer {i}: {query[:100]}...")
    response = customer_support_chat(query, "general", 500)
    print(f"🤖 Senior Support Agent: {response}")
    print("-" * 60)
# Out:
# 🔥 COMPLEX CUSTOMER ISSUES:
#
# 👤 Frustrated Customer 1: I've been trying to use your service for a week but keep running into problems. First, my account wa...
# 🤖 Senior Support Agent: I apologize for any frustration you're experiencing while using our service. It's important that we resolve these issues as soon as possible. Let's start with the first problem: your account wasn't activated properly. We can take care of that by reaching out to our customer support team and providing them with your details. They will be able to assist you in activating your account correctly.
#
# Next, let's address the issue with accessing the main features. Could you please provide us with more information about the specific problems you're facing? This will help us identify the root cause and find a solution to ensure a smooth experience for you.
#
# Lastly, regarding the billing issue, we apologize for any confusion or surprise caused by the charges you didn't sign up for. Our finance team is available to review your account and make any necessary adjustments to ensure accuracy and fairness.
#
# Please don't hesitate to reach out to our dedicated customer support team during business hours at [Customer Support Phone Number] or through the Live Chat on our website at [Website URL]. We value your satisfaction and are committed to resolving these issues promptly.
# ------------------------------------------------------------
#
# 👤 Frustrated Customer 2: I'm a business owner looking to switch from your competitor. I need to know: 1) Can you migrate our ...
# 🤖 Senior Support Agent: I'll make sure to provide you with the necessary information about switching from our competitor. Here's what you need to know:
#
# 1. Migrating Data: We understand that you want to transfer your existing data to us. Our dedicated team will work closely with you to ensure a seamless transition. Please provide us with your specific details, and we'll take care of the rest.
#
# 2. Onboarding Process: To help you integrate our platform into your business, we have a structured onboarding process. It typically includes a consultation meeting, system configuration, and user training. Our team will guide you through each step to ensure a successful implementation.
#
# 3. Training for Your Team: Yes, we do offer training for your team. Our experts will conduct a thorough training session to familiarize them with our platform and its features. This will enable your team to leverage our solutions effectively and maximize the benefits they offer.
#
# 4. Post-Implementation Support: Once you've implemented our platform, we're committed to providing ongoing support. Our dedicated customer support team is available to assist you with any questions or concerns you may have. We also offer regular updates, tutorials, and resources to keep you informed and up-to-date.
#
# We're here to support you every step of the way as you make the switch to our platform. Feel free to reach out to us if you have any further questions or need additional guidance.
# ------------------------------------------------------------
#
# 👤 Frustrated Customer 3: I bought your premium subscription last month, but I'm not satisfied with the performance. The app i...
# 🤖 Senior Support Agent: I understand that you're experiencing difficulties with our premium subscription and are seeking a solution. We apologize for any frustration caused by the performance issues and lack of customer support. To address this situation, we recommend reaching out to our dedicated team for further assistance. They can guide you through the necessary steps to resolve your concerns and ensure a smooth resolution. Please provide us with your contact information so we can connect you directly.
# ------------------------------------------------------------

# %%
conversation_turns = [
    "Hello, I need help with my recent order.",
    "My order number is #12345. It was supposed to arrive yesterday but I haven't received it.",
    "I checked the tracking and it says 'delivered' but there's nothing at my door.",
    "Yes, I've checked with my neighbors and building management. No one has seen the package.",
    "Okay, I'll file a claim. How long does that usually take?"
]

print("💬 Simulating Multi-Turn Customer Conversation:")
for i, turn in enumerate(conversation_turns, 1):
    print(f"\n👤 Customer Turn {i}: {turn}")
    response = customer_support_chat(turn, "general", 250)
    print(f"🤖 Support Agent: {response}")
    print("-" * 40)
# Out:
# 💬 Simulating Multi-Turn Customer Conversation:
#
# 👤 Customer Turn 1: Hello, I need help with my recent order.
# 🤖 Support Agent: I'm here to assist you! Please provide me with more details about the issue you're facing with your recent order so that I can provide the most appropriate guidance.
# ----------------------------------------
#
# 👤 Customer Turn 2: My order number is #12345. It was supposed to arrive yesterday but I haven't received it.
# 🤖 Support Agent: I'm sorry to hear that you haven't received your order with the order number #12345 as expected. Our team is here to assist you in resolving this issue. To better understand the situation, could you please provide more details about what happened? This will help us take the necessary steps to ensure your order arrives on time.
# ----------------------------------------
#
# 👤 Customer Turn 3: I checked the tracking and it says 'delivered' but there's nothing at my door.
# 🤖 Support Agent: We apologize for the confusion you may have experienced regarding the delivery of your package. It's possible that the package was delivered to a different address or that it was mistakenly labeled as 'delivered' without actually being placed in your mailbox. To resolve this issue, we recommend reaching out to our customer service team who can assist you further in verifying the status of your delivery and resolving any discrepancies. They will be able to provide you with more specific information about the delivery and guide you through the necessary steps to ensure that your package reaches you safely.
# ----------------------------------------
#
# 👤 Customer Turn 4: Yes, I've checked with my neighbors and building management. No one has seen the package.
# 🤖 Support Agent: I understand that you have checked with your neighbors and building management and have not yet received any information about your package. To further assist you in resolving this matter, could you please provide more details such as the delivery address, the package number or tracking number, and any other relevant information? This will help us narrow down the potential reasons for the missing package and find a solution to ensure its safe delivery to you.
# ----------------------------------------
#
# 👤 Customer Turn 5: Okay, I'll file a claim. How long does that usually take?
# 🤖 Support Agent: We're glad you're taking the initiative to file a claim! The time it takes to process a claim can vary depending on the specific circumstances of your situation and the policies of the company you're dealing with. Typically, it can take anywhere from a few days to several weeks. We'll do our best to expedite the process for you, so please keep us updated on any progress or concerns you may have along the way.
# ----------------------------------------
