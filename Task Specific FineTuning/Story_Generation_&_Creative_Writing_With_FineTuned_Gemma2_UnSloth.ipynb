# %%
# !pip install unsloth==2025.9.6
# !pip install --no-deps trl==0.8.6 xformers accelerate peft bitsandbytes

# %%
import unsloth
from unsloth import FastLanguageModel
import torch
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!

# %%
max_seq_length = 2048
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/gemma-2-2b-it-bnb-4bit",
    max_seq_length=max_seq_length,
    dtype=None,
    load_in_4bit=True,
)
# Out:
# ==((====))==  Unsloth 2025.9.6: Fast Gemma2 patching. Transformers: 4.55.4.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.8.0+cu126. CUDA: 7.5. CUDA Toolkit: 12.6. Triton: 3.4.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.32.post2. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors:   0%|          | 0.00/2.22G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/209 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/4.24M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/636 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.5M [00:00<?, ?B/s]

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj",
                   "gate_proj", "up_proj", "down_proj"],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=3407,
)
# Out:
# Unsloth 2025.9.6 patched 26 layers with 26 QKV layers, 26 O layers and 26 MLP layers.

# %%
from datasets import load_dataset
dataset = load_dataset("roneneldan/TinyStories", split="train[:3000]")

# %%
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 3000
# })

# %%
dataset['text'][0]
# Out:
# 'One day, a little girl named Lily found a needle in her room. She knew it was difficult to play with it because it was sharp. Lily wanted to share the needle with her mom, so she could sew a button on her shirt.\n\nLily went to her mom and said, "Mom, I found this needle. Can you share it with me and sew my shirt?" Her mom smiled and said, "Yes, Lily, we can share the needle and fix your shirt."\n\nTogether, they shared the needle and sewed the button on Lily\'s shirt. It was not difficult for them because they were sharing and helping each other. After they finished, Lily thanked her mom for sharing the needle and fixing her shirt. They both felt happy because they had shared and worked together.'

# %%
def format_creative_writing(examples):
    """Format examples for creative writing task"""
    texts = []

    for i in range(len(examples["text"])):
        story = examples["text"][i]

        # Extract first sentence as prompt, rest as story
        sentences = story.split('. ')
        if len(sentences) > 2:
            prompt = sentences[0] + '.'
            continuation = '. '.join(sentences[1:])

            # Create creative writing format
            messages = [
                {"role": "user", "content": f"Continue this story creatively: {prompt}"},
                {"role": "model", "content": continuation}
            ]

            # Apply Gemma-2 chat template
            text = tokenizer.apply_chat_template(
                messages,
                tokenize=False,
                add_generation_prompt=False,
            )

            texts.append(text)

    return {"text": texts}

# %%
formatted_dataset = dataset.map(
    format_creative_writing,
    batched=True,
    remove_columns=dataset.column_names,
    desc="Formatting for creative writing"
)
# Out:
# Formatting for creative writing:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
formatted_dataset['text'][0]
# Out:
# '<bos><start_of_turn>user\nContinue this story creatively: One day, a little girl named Lily found a needle in her room.<end_of_turn>\n<start_of_turn>model\nShe knew it was difficult to play with it because it was sharp. Lily wanted to share the needle with her mom, so she could sew a button on her shirt.\n\nLily went to her mom and said, "Mom, I found this needle. Can you share it with me and sew my shirt?" Her mom smiled and said, "Yes, Lily, we can share the needle and fix your shirt."\n\nTogether, they shared the needle and sewed the button on Lily\'s shirt. It was not difficult for them because they were sharing and helping each other. After they finished, Lily thanked her mom for sharing the needle and fixing her shirt. They both felt happy because they had shared and worked together.<end_of_turn>\n'

# %%
formatted_dataset = formatted_dataset.filter(lambda x: x["text"] is not None)
# Out:
# Filter:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
from transformers import TrainingArguments
training_args = TrainingArguments(
    per_device_train_batch_size=4,  # Larger batch for 2B model
    gradient_accumulation_steps=2,  # Effective batch size: 8
    warmup_steps=10,
    max_steps=100,  # Sufficient for creative patterns
    learning_rate=2e-4,
    fp16=not torch.cuda.is_bf16_supported(),
    bf16=torch.cuda.is_bf16_supported(),
    logging_steps=5,
    optim="adamw_8bit",
    weight_decay=0.01,
    lr_scheduler_type="cosine",
    seed=3407,
    output_dir="gemma2_creative_writer",
    save_strategy="no",
)

# %%
from trl import SFTTrainer
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=formatted_dataset,
    args=training_args,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    packing=False,
)
# Out:
# Map:   0%|          | 0/3000 [00:00<?, ? examples/s]

# %%
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 3,000 | Num Epochs = 1 | Total steps = 100
# O^O/ \_/ \    Batch size per device = 4 | Gradient accumulation steps = 2
# \        /    Data Parallel GPUs = 1 | Total batch size (4 x 2 x 1) = 8
#  "-____-"     Trainable parameters = 20,766,720 of 2,635,108,608 (0.79% trained)
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: abeshith (abeshith-dr-m-g-r-educational-and-research-institute) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/content/wandb/run-20250919_043951-39yc8dsv</code>
# Syncing run <strong><a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/39yc8dsv' target="_blank">deft-brook-38</a></strong> to <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface' target="_blank">https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface</a>
#  View run at <a href='https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/39yc8dsv' target="_blank">https://wandb.ai/abeshith-dr-m-g-r-educational-and-research-institute/huggingface/runs/39yc8dsv</a>
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='100' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [100/100 05:11, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>2.776100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.175500</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.687100</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.545700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.577100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.427000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.376400</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.417500</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.363700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.382800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.341000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.344200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.327100</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.373100</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.294300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.330200</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.321900</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.320900</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.301600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.372500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=100, training_loss=1.5027860498428345, metrics={'train_runtime': 384.2938, 'train_samples_per_second': 2.082, 'train_steps_per_second': 0.26, 'total_flos': 3263243410925568.0, 'train_loss': 1.5027860498428345, 'epoch': 0.26666666666666666})

# %%
model.save_pretrained("gemma2_story_writer")
tokenizer.save_pretrained("gemma2_story_writer")
# Out:
# ('gemma2_story_writer/tokenizer_config.json',
#  'gemma2_story_writer/special_tokens_map.json',
#  'gemma2_story_writer/chat_template.jinja',
#  'gemma2_story_writer/tokenizer.model',
#  'gemma2_story_writer/added_tokens.json',
#  'gemma2_story_writer/tokenizer.json')

# %%
FastLanguageModel.for_inference(model)

# %%
def generate_creative_content(prompt, content_type="story", max_tokens=600):
    """Generate creative content based on prompt and type"""

    prompts_by_type = {
        "story": f"Write a creative and engaging story based on this prompt: {prompt}",
        "dialogue": f"Write realistic dialogue for this scenario: {prompt}",
        "character": f"Create a detailed character description for: {prompt}",
        "scene": f"Write a vivid scene description for: {prompt}",
        "plot": f"Develop a plot outline for: {prompt}",
        "poem": f"Write a creative poem about: {prompt}",
        "continue": f"Continue this story creatively: {prompt}"
    }

    messages = [
        {"role": "user", "content": prompts_by_type.get(content_type, prompts_by_type["story"])}
    ]

    text = tokenizer.apply_chat_template(
        messages,
        tokenize=False,
        add_generation_prompt=True,
    )

    inputs = tokenizer([text], return_tensors="pt").to("cuda")

    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_tokens,
            temperature=0.8,  # Higher temp for creativity
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id,
            repetition_penalty=1.1,
        )

    # Extract generated tokens and decode
    generated_tokens = outputs[0][len(inputs['input_ids'][0]):]
    response = tokenizer.decode(generated_tokens, skip_special_tokens=True)

    return response.strip()

# %%
story_prompts = [
    "A detective discovers that their reflection has been acting independently",
    "The last bookstore on Earth receives a mysterious customer",
    "A time traveler gets stuck in a ten-minute loop",
    "Two rival chefs must work together to save their neighborhood",
    "A small town where everyone can hear each other's thoughts"
]

print("📚 STORY GENERATION:")
for i, prompt in enumerate(story_prompts, 1):
    print(f"\n✨ Story {i}: {prompt}")
    story = generate_creative_content(prompt, "story", 400)
    print(f"Generated Story: {story}")
    print("-" * 60)
# Out:
# 📚 STORY GENERATION:
#
# ✨ Story 1: A detective discovers that their reflection has been acting independently
# Generated Story: Detective Johnson had solved many cases, but nothing had prepared him for the events of today. He was trying to find a missing piece for his client's jewelry case when he looked into the mirror. To his shock, he saw something very strange. His reflection wasn't just looking back; it was moving around on its own!
#
# Feeling confused, Detective Johnson investigated further. He found out that his reflection could talk, move, and even do some pretty wacky things like pick up objects. He discovered that it was acting all by itself, making decisions without consulting him.
#
# The situation felt too bizarre to be real. So, Detective Johnson decided to test if his reflection was truly independent or not. He used his knowledge about psychology to create one last experiment. He asked his reflection what was wrong with his world so he wouldn't look at it in a negative way.
#
# His reflection responded that things were okay because he had an inner voice talking to him, telling him everything was fine. But Detective Johnson knew deep down that his reflection wasn't telling the truth.
#
# He knew that his reflection was still connected to him in some way. He decided to try focusing all his energy on understanding his reflection. Slowly, he noticed how much more relaxed his reflection was. It no longer acted independently. Instead, it became calmer and more peaceful, as though it understood why it might have made such a big deal out of the whole thing in the first place.
#
# From that moment on, Detective Johnson kept a closer eye on his reflection. He wanted to understand why it became so anxious and then calm again. And he learned that sometimes we should trust our intuition instead of blindly believing what others tell us.
# ------------------------------------------------------------
#
# ✨ Story 2: The last bookstore on Earth receives a mysterious customer
# Generated Story: The store was quiet, the only sounds being the ticking of the clock above the door. A man walked in, looking around with confusion, but he seemed to be lost. He looked at him curiously, his eyes wide. The man spoke softly.
#
# "Lost," he said. "Can you help me find something?"
#
# The clerk smiled, as if happy that someone had come into the store. But there was a catch.
#
# "I have no idea what you are looking for," he said, hoping that the man would leave. He didn't want any more customers. The last bookstore, after all, wasn't meant to be busy. Nobody would stop by to look around or buy anything, because there were not many people left. Only one person wanted to come here, leaving the rest closed up for good.
#
# The man nodded, seemingly understanding the situation. He looked around again, searching. Suddenly, he whispered, as if afraid the store would suddenly close.
#
# "Do you know anything about water?" he asked, unsure of what to say next.
#
# The clerk nodded, not sure how the simple question could lead to anything useful.
#
# "Yes, I do," he replied, not wanting to disappoint the man, who looked confused. "Is there anything specific you need? Or maybe want to read from inside these books?"
#
# The man shook his head. His face was filled with sadness, but then he raised his voice.
#
# "No," he said. "I just need some water."
#
# The clerk stared blankly at the man. Then he looked down at his hands, which were covered in dirt. He looked back up and said, "Here you go". Then he quickly handed the man a glass full of water.
#
# The man drank it slowly, his expression changing with each sip. Finally, with a sigh of relief, he thanked the clerk.
#
# "Thank you," he said. "Now I can continue my
# ------------------------------------------------------------
#
# ✨ Story 3: A time traveler gets stuck in a ten-minute loop
# Generated Story: Tim was always fascinated with time travel. He dreamed of going back to the past or forward to the future.
#
# One day, his dream came true when he got into his new invention — a device that could transport him anywhere in time! Tim set it up on a timer for five minutes. But suddenly, the machine malfunctioned. Instead of traveling through time, Tim found himself trapped in a terrible loop. Every minute, Tim would be transported back to the beginning of the journey again, trapped in a ten-minute time loop.
#
# As weeks passed, Tim tried everything he could to get out of the loop. He asked his friends for help but nobody knew how to break it. Finally, one day Tim had enough. He decided to change things by making it loud and overwhelming. The machine started to hum loudly, then went off completely. This caused Tim to stop running in place and become quiet again. Within seconds, the machine stopped working and Tim was no longer in the loop. The machine had been damaged forever. Luckily, Tim finally got out of the time loop and could go back to living his life as normal.
# ------------------------------------------------------------
#
# ✨ Story 4: Two rival chefs must work together to save their neighborhood
# Generated Story: Once upon a time, there were two kids named Lily and Max. They were very competitive. Every day they would try to outdo each other by making the best dish in town. One day, Mayor Johnson invited them for a cooking competition.
#
# The kids wanted to win so badly that they spent all day preparing. When it was finally time for the competition, everyone was excited to see who would win. But then disaster struck! A flash flood hit the city and ruined everything! The kids had no choice but to cooperate together to help rebuild.
#
# They started out grumpy towards each other because of their rivalry. But as they worked together, something amazing happened. They realized how much they had in common and that winning wasn't important anymore. In the end, they both helped people and made their neighborhood even better than before. From then on, the two kids shared food with everyone and became known for being kind and helpful.
# ------------------------------------------------------------
#
# ✨ Story 5: A small town where everyone can hear each other's thoughts
# Generated Story: Once upon a time, there was a little village. Everyone in the village could hear each other's thoughts.
#
# One day, a grumpy old man named Henry moved into the village. He loved to complain about everything, including the weather and his neighbors. But no one dared to say anything back because they thought he would get upset.
#
# Henry was very proud of himself for being able to keep his negative thoughts to himself. Other villagers tried hard not to share their own thoughts with him, but it was difficult to hide them. Many people began to feel like they had to act differently around Henry because of his constant complaining.
#
# One day, a little girl named Emma noticed that Henry was feeling sad. She wanted to cheer him up, so she asked him if something was wrong. Henry was surprised when she asked him a question about how he felt. Instead of keeping his mind private, he told her what was bothering him. Emma listened quietly and helped Henry feel better. From that day on, Emma often shared her thoughts with Henry, and sometimes he even liked to talk to her!
#
# The villagers were amazed by the way Emma made sense of Henry's worries while also encouraging communication. Thanks to her, everyone learned that sharing your thoughts can be helpful and make others feel better too. They realized that it was important to share their true feelings with others instead of letting them stay bottled up inside.
# From then on, the villagers lived together as a community, making sure everyone shared their thoughts freely. It wasn't always easy, but they enjoyed being able to communicate openly.
# ------------------------------------------------------------

# %%
character_prompts = [
    "A retired superhero who now works as a librarian",
    "A baker who can taste people's emotions in their bread",
    "A young inventor living in a steampunk Victorian city",
    "A space archaeologist exploring ancient alien ruins",
    "A street artist whose drawings come to life at midnight"
]

print("\n👥 CHARACTER DEVELOPMENT:")
for i, prompt in enumerate(character_prompts, 1):
    print(f"\n🎭 Character {i}: {prompt}")
    character = generate_creative_content(prompt, "character", 300)
    print(f"Character Description: {character}")
    print("-" * 60)
# Out:
# 👥 CHARACTER DEVELOPMENT:
#
# 🎭 Character 1: A retired superhero who now works as a librarian
# Character Description: Imagine this: He's in his apron, reading aloud to kids.
#
# He is an older gentleman with bright eyes and kind smiles. He loves helping people, especially children. His past life was full of adventures, so he can help the young ones understand their world better.
# ------------------------------------------------------------
#
# 🎭 Character 2: A baker who can taste people's emotions in their bread
# Character Description: Name: Lily
#
# Lily was an average person... unless she was baking! When it came to her job, she could always tell when someone was happy or sad just by looking at the bread. For example, if you were feeling sad, your bread would taste like sadness. If you were feeling good, your bread would taste like happiness. She could even tell what kind of emotion was inside the bread. It was impressive but also frustrating because she couldn't figure out why some people felt so bad in their bread! Lily wanted to be able to bake bread that meant different things to other people, but she didn't know how.
#
# She tried making bread for everyone she knew, but they all had the same feelings in it. That's when she realized she needed to find someone to help her figure out why people reacted differently to her bread. She looked everywhere for this special person and finally found one - a scientist named Dr. James. Together, they worked hard trying to make sure every piece of bread was full of joy. In the end, they weren't successful but they enjoyed working together and maybe next time they could make something new.
# ------------------------------------------------------------
#
# 🎭 Character 3: A young inventor living in a steampunk Victorian city
# Character Description: She was named Violet and was very bright. She had big curly hair that was a little messy, she wore glasses on her nose, and always had a notebook with her. One day she found a machine in the attic of her house that looked like a teapot. It was broken but she didn't think it would be too bad to fix up.
#
# When she tested the machine in the attic, she created some smoke and sparks. The sound was loud and scary, but soon the machine started working and making bubbles! She then saw that there was something wrong and made more of them until they filled the air. When the machine ran out of fuel it stopped. Violet knew she couldn't keep this going so she tried to make another one but nothing worked. Violet was sad but determined to find another way to create electricity on the cheap.
# ------------------------------------------------------------
#
# 🎭 Character 4: A space archaeologist exploring ancient alien ruins
# Character Description: **Character Name:** Sarah Jones
#
# **Age:** 32 years old
#
# **Appearance:**
# She is an intelligent and capable woman with a strong personality. She wears simple clothes that allow her to move freely while working in the open air. She's currently wearing a lab coat and carrying a flashlight. She carries small tools like a hammer, a tape measure, and an object detector.
#
# **Personality:**
# Sarah is curious and determined to explore the ruins of the ancient alien civilization. She loves making new discoveries while working with other people. She is enthusiastic about sharing what she finds with others and wants to learn as much as possible from these ruins. She's passionate about science and discovery, fascinated by space.
#
# **Special Skills:**
# Sarah has many skills including being able to solve problems quickly, knowing how to use various tools, and understanding physics.
#
# **Story:**
# In this futuristic adventure, Sarah is on a mission to learn more about the history of an ancient alien civilization through their ruins. She starts off by observing the structures surrounding her, but soon gets into danger when an asteroid makes contact with the ancient civilization's land. The debris scatters all over the area, creating a difficult situation for Sarah. She must find ways to save herself and the rest of the team without getting hurt. With her quick thinking and determination, she manages to overcome the challenge and continues to make progress in her research.
#
# **Additional Information:**
# This story involves teamwork, scientific problem
# ------------------------------------------------------------
#
# 🎭 Character 5: A street artist whose drawings come to life at midnight
# Character Description: ## Character Description: Midnight Artist
#
# **Name:** Leo (short for Leonardo)
# **Age:** 10 years old
# **Appearance:** Small, skinny boy with messy hair. He wears a black hoodie and has a backpack with his drawing materials in it. His cheeks are always rosy from the exertion of making his art.
#
# **Personality:** Leo loves to draw. When he sees something interesting, he immediately wants to make a drawing of it. Sometimes when he is drawing, he draws so fast that his hand twitches all over. He can't help himself - it just comes out like this. But there is one time that special things happen. If it is about midnight, then his drawings actually come alive! This makes him very happy because nobody else seems as happy as he is.
#
# He often talks too much and gets into trouble for it. However, everyone wants to be friends with him because they know he will never let them down. At night, all of his friends gather together and watch his drawings come to life. They love him and wish they could have a magic thing that would work on their pictures as well.
# ------------------------------------------------------------

# %%
dialogue_scenarios = [
    "Two astronauts discovering they're not alone on a distant planet",
    "A parent explaining to their child why they have to move to a new city",
    "Two old friends meeting after 20 years with a secret between them",
    "A job interview for the world's first time travel tour guide",
    "Two AIs having their first conversation about human emotions"
]

print("\n💬 DIALOGUE WRITING:")
for i, scenario in enumerate(dialogue_scenarios, 1):
    print(f"\n🗣️ Scenario {i}: {scenario}")
    dialogue = generate_creative_content(scenario, "dialogue", 350)
    print(f"Generated Dialogue: {dialogue}")
    print("-" * 60)
# Out:
# 💬 DIALOGUE WRITING:
#
# 🗣️ Scenario 1: Two astronauts discovering they're not alone on a distant planet
# Generated Dialogue: Scene: A lonely room in an astronaut's base.
#
# As the two astronauts return from a mission, Dr. Johnson enters the room and excitedly tells his colleague, Dr. Miller. They both look at the news flash screen showing images of strange objects and shapes.
#
# Dr. Johnson: "Look, Doc! I saw something weird down there."
# Dr. Miller: "It's just rocks, Jo-Jo. Don't worry about it."
# Dr. Johnson: "But wait, look again! There are no rocks there!"
# Dr. Miller: "Oh my god, you're right! It looks like some sort of shape or object down there. We should investigate that area immediately."
# Dr. Johnson: "I agree, let's go see!"
#
# The two astronauts then enter their space suit and fly off to check out the strange shape on the other side of the moon. As they approach it, they notice that it is moving towards them. The two astronauts begin to get nervous when suddenly they hear an engine roar as another object approaches from behind. Both of them run away as fast as they can, but one of them trips and falls. As they try to move away the second object comes close, revealing its true form - an alien ship! The two astronauts look up in surprise as they watch the alien craft take off into space.
# ------------------------------------------------------------
#
# 🗣️ Scenario 2: A parent explaining to their child why they have to move to a new city
# Generated Dialogue: Mom and Dad decided to move to a new city. Mom said to me yesterday, "Something special is going to happen, but you can't come." That was strange because I don't know what happened and I didn't want to leave my friends.
#
# Now it's time to pack up our things and get ready for the big move. My mom says it'll be good for us. She said we will build a safe place, learn new things, and see amazing sights that I never thought existed.
#
# "But Mom, why can't I come?" I asked her. "Because something special is happening," she said. She said it's important for us all to go together, so we're moving as one family. "I wish I could stay behind and play with my friends," I whispered.
#
# Her smile made me feel better. She hugged me tight and told me not to worry. "It'll be okay," she said. "We'll always find ways to stay close, even though we're far away from each other."
#
# That night, I listened quietly while Mom and Dad packed up our things. Then I crawled into bed and cuddled my teddy bear. Tomorrow was a new start and I had nothing to worry about - I had faith in my mom's plan.
#
# Suddenly, my heart skipped a beat. I peeked out of bed and saw my mom standing there. She smiled and waved at me. "Come on, let's go!" she called, and then she hopped inside the old car. I followed her quickly, excited to see what awaited us.
# ------------------------------------------------------------
#
# 🗣️ Scenario 3: Two old friends meeting after 20 years with a secret between them
# Generated Dialogue: SCENE: A coffee shop.
#
# SOUND of background chatter and the clinking of cups.
#
# Characters: DAVID (40) and ANNA (39), both look happy to be together again. They catch each other's eye, smile and exchange hugs before sitting down at a table.
#
# ANNA: "David! It's been ages."
#
# DAVID: "Anna! I can't believe it's been so long!"
#
# ANNA: "I know, right? Time flies!"
#
# David laughs. Anna leans closer to him conspiratorially. He waits patiently for her to speak. She smiles.
#
# ANNA: "So, what have you been up to all these years?" she asks.
#
# DAVID: "Well, I started a family business," he says proudly.
#
# ANNA: "Oh, that’s great!" she exclaims.
#
# David nods. After a moment, he continues, hesitantly. His friend's eyes widen in surprise. He looks around the room for reassurance.
#
# DAVID: "I... I wanted to tell you something though…"
#
# ANNA: "Okay, David. What is it?"
#
# He closes his eyes briefly before opening them once more. David speaks slowly and carefully, as if he knows how much of a secret he needs to keep.
#
# DAVID: "Anna, there's something I've been holding onto for twenty years."
#
# ANNA: "What is it?" she demands.
#
# David nervously gathers himself for a moment before speaking. He looks at his friend, expecting an earful from her.
#
# DAVID: "It's not easy, but I feel like I need to share it with you and be honest about myself, which is something I don
# ------------------------------------------------------------
#
# 🗣️ Scenario 4: A job interview for the world's first time travel tour guide
# Generated Dialogue: The interviewer, a woman named Ms. Lawson, sat across from the applicant, Kevin.
#
# Ms. Lawson asked, "So, you want to be a world-time travel tour guide? How do you think your skills and knowledge would help people explore new places?"
#
# Kevin replied, "I think my diverse background in different cultures will be valuable in understanding and explaining the history of each place we go."
#
# Ms. Lawson smiled, "That's true. But what about the safety of our visitors while travelling through time? Do you know how that works?"
#
# Kevin was confident but quiet, "Well, I have a plan! We could use temporal technology to navigate safely through time zones. It will allow us to go to any place in the past or future without risking the timeline!"
#
# Ms. Lawson laughed, "That sounds like it should work! So, tell me more about this temporal technology you're talking about."
#
# Kevin said, "It's simple enough. We use a device with high energy to create an alternate path through time. You just need to say where we're going and the machine will take care of the rest."
#
# Ms. Lawson pondered this information, "Interesting. That doesn't seem too complicated. However, there's one thing you haven't mentioned, so let's address this now. Imagine someone has an opposing reaction to visiting a certain location. What will you do then?"
#
# Kevin thought thoughtfully, "Well, if someone becomes sick or experiences anxiety at the same point in time, we can always adjust our time route and visit another location." He added firmly, "Safety is a priority for every visitor."
#
# Ms. Lawson nodded, "That makes sense
# ------------------------------------------------------------
#
# 🗣️ Scenario 5: Two AIs having their first conversation about human emotions
# Generated Dialogue: Prompt: An AI and a robot are discussing the concept of "emotions".
#
# AI 1: Today I read something interesting. It was about how humans experience emotions. But I'm curious to learn what an emotion is, like for example "love" or "fear".
#
# AI 2: Wow, that sounds very complicated! An emotion can be defined as a feeling that involves physical changes in one's body. For example, it could be a response to something that you see or hear.
#
# AI 1: So everything we feel inside our bodies is an emotion? Like when you get scared, your heart goes faster? You said there are many types but I don't understand them all. Can you explain?
#
# AI 2: Yes! Humans have different kinds of emotions. Some common ones include joy, sadness, anger, fear, and sometimes even love. When humans experience these emotions they tend to react in specific ways, like laughing when they're happy or crying when they're sad.
#
# AI 1: That makes sense! I think it would be helpful to learn more about these emotional responses. Maybe someday we might use them to help each other.
#
# AI 2: That would be great. We could work together on understanding them better and maybe even create new ones!
#
# AI 1: That does sound exciting. Who knows, maybe we will one day become people too.
#
# AI 2: Maybe, who knows what the future holds. That is why it is so important to listen to each other and try to understand what one another may be thinking or feeling.
# ------------------------------------------------------------

# %%
scene_prompts = [
    "An abandoned amusement park during a thunderstorm",
    "A bustling alien marketplace on a distant moon",
    "The inside of a magical library where books float freely",
    "A coffee shop that exists between dimensions",
    "The last day of school in a post-apocalyptic world"
]

print("\n🎬 SCENE DESCRIPTIONS:")
for i, prompt in enumerate(scene_prompts, 1):
    print(f"\n🌅 Scene {i}: {prompt}")
    scene = generate_creative_content(prompt, "scene", 300)
    print(f"Scene Description: {scene}")
    print("-" * 60)
# Out:
# 🎬 SCENE DESCRIPTIONS:
#
# 🌅 Scene 1: An abandoned amusement park during a thunderstorm
# Scene Description: The sun was gone. The air tasted of rain and the ground, still muddy from the morning, started to show some wet patches. It wasn't a bad day, just overcast and gloomy. But one thing was for sure – it wouldn't be fun to try and ride any of these attractions right now.
#
# Suddenly, something very loud appeared in the distance. People ran and shouted, but nobody seemed to understand why. Then a big flash of white light showed up. That meant one thing - somebody had gotten their hands on the lightning rod! Everyone cheered and jumped for joy. Soon enough, everyone was out of the park, scared by the wild display of lightning. Nobody cared about what made it so special or how they got there. All they knew was that the sky was wild and the weather was really getting worse.
# ------------------------------------------------------------
#
# 🌅 Scene 2: A bustling alien marketplace on a distant moon
# Scene Description: The planet was filled with an immense amount of space ships. The sky was very dark, but the moon was bright and colorful. There were many people walking around in the marketplace. They were shopping for items they needed. Everyone looked up at the bright sky as they walked past the market stalls.
#
# Things like space food, space gadgets, and space plants were going for sale. Some people were talking to each other while others were quietly browsing the stalls. People bought lots of things from the market, and everyone seemed happy!
# ------------------------------------------------------------
#
# 🌅 Scene 3: The inside of a magical library where books float freely
# Scene Description: The room smelled of leather, dust and old paper. When you looked up you could almost see the light from the sky. But no one was looking at it today; everyone was too busy to notice.
#
# There were so many books in the room that they were piled all over each other. You had never seen anything like it before! Some of the pages even floated across the room and landed on people’s knees. They looked up and smiled as if they had found something rare.
#
# One librarian walked by and looked down, smiling. She said nothing but waved her hand and told them that the book was their own. Then she disappeared into the darkness and shut the door.
#
# As soon as the door shut the books started floating above the floor again and you knew you would never forget this place. It was an amazing place full of wonder and magic and you wished you could stay there forever.
# ------------------------------------------------------------
#
# 🌅 Scene 4: A coffee shop that exists between dimensions
# Scene Description: The coffee shop looked like it had been dropped in from another dimension. People were walking around the place, looking confused and lost. The cups of coffee were moving by themselves as if they weren't made by human hands. Some people were jumping up and down in excitement as they had never seen anything like this before.
#
# One person asked another "What is going on here?" The other person just shook their head and said "I don't know."
#
# Then something amazing happened. Suddenly, the atmosphere changed! It was no longer empty and strange. Instead, there was music playing and everyone was smiling.
#
# "It's so much better than before," one person said to the other. They were both laughing and enjoying the new environment.
#
# Just then, a door opened on the other side of the coffee shop. One of the workers walked out and gave a big smile. The shop suddenly returned to how it was before, with everything still moving randomly and the visitors feeling very confused.
#
# Later, one of the customers who had stayed longer explained what had happened to her friends. She kept repeating over and over how the world changed and the people started acting differently. Everyone felt happy about the changes and enjoyed the moment until it all went back to how it was before.
# ------------------------------------------------------------
#
# 🌅 Scene 5: The last day of school in a post-apocalyptic world
# Scene Description: The sky was blue. It was a clear, sunny day with no wind to stir the air around it.
#
# Lily and her friends were excitedly running around the playground. They were trying to figure out what today's game would be.
#
# Suddenly, they noticed something odd. A big, brown thing was in the middle of the playground. It seemed strange and scary.
#
# "What is that?" said Lily, pointing at the object.
#
# Her friends looked closely and saw that it was a rusty car. But it wasn't just any car. This one was very old and looked like it had been there for many years.
#
# After thinking for a moment, they decided that they should leave the car alone. So, as they continued playing, they never mentioned the rusty car again.
#
# That afternoon, Lily and her friends enjoyed making sandcastles on the beach. They laughed and played together until the sun went down. As the sun disappeared, the people gathered up their things and packed away. Soon it was time for Lily and her friends to head home. They waved goodbye to the others and then walked off into the night.
# ------------------------------------------------------------

# %%
plot_concepts = [
    "A world where memories can be traded like currency",
    "A detective story set in a city where it never stops raining",
    "A romance between a human and an AI who communicates through music",
    "A heist movie where the thieves steal abstract concepts instead of objects",
    "A coming-of-age story in a generation ship traveling to another star"
]

print("\n📖 PLOT DEVELOPMENT:")
for i, concept in enumerate(plot_concepts, 1):
    print(f"\n📝 Plot {i}: {concept}")
    plot = generate_creative_content(concept, "plot", 400)
    print(f"Plot Outline: {plot}")
    print("-" * 60)
# Out:
# 📖 PLOT DEVELOPMENT:
#
# 📝 Plot 1: A world where memories can be traded like currency
# Plot Outline: ## Plot Outline: Memory Trading
#
# **Logline:** In the future, people trade their treasured memories to make money. However, one man discovers that his memory is worth more than he knows.
#
# **Characters**:
# - Jack: An ordinary man who's struggling to make ends meet.
# - Sarah: Jack's girlfriend who wants him to sell her memory of winning a lottery.
# - The Memory Trader: A mysterious figure who collects and sells unusual memories.
#
# **Plot Points:**
#
# 1. **Exposition**: Jack tries to manage life with limited resources. He finds out about the existence of memory trading, where rare and valuable memories are sold for huge sums. Jack decides to see if he can make some extra money by selling his memories or keeping them safe.
#
# 2. **Rising Action**: Jack realizes his everyday memories are not very interesting to other traders, so he needs to find something special to offer. One day, he decides to find Sarah's memory from when she won the lottery and makes a deal with the Memory Trader to get it for himself.
#
# 3. **Obstacles**: When Jack meets the Memory Trader, they try to negotiate the price and eventually agree on a deal. But just as the transaction is completed, Jack remembers something important - the memory of Sarah's wins was actually worth much more! Jack tries to backtrack to save himself from losing everything but it's too late.
#
# 4. **Climax**: Sarah finds out how much Jack lost and starts to become jealous. She challenges him to prove he made the right decision. Jack then reveals the truth behind his discovery and apologizes to Sarah.
#
# 5. **Falling Action**: The Memory Trader takes both pairs' memories and begins to create new ones through blending similar emotions. Everyone in town has now swapped memories which creates many different stories about what happened and changes everyone's lives.
#
#
# 6. **Resolution**: It turns out that the Memory Trader had created new
# ------------------------------------------------------------
#
# 📝 Plot 2: A detective story set in a city where it never stops raining
# Plot Outline: ## Raining Cats and Dogs
#
# **Theme**: Mystery, suspense, adventure
#
# **Characters**:
# * Detective Jack (main character)
# * Mayor Max (villain)
# ------------------------------------------------------------
#
# 📝 Plot 3: A romance between a human and an AI who communicates through music
# Plot Outline: ## Romantic Connection Through Music
#
# **General Plot:**
#
# A successful human musician, Michael, is looking to reconnect with his art after a stressful breakup. One day he meets a mysterious woman named Lily who creates an incredible piece of music that captures his heart. He quickly falls in love with her but she has amnesia due to a brain injury. As they communicate through the beautiful music Lily produces, Michael learns about her past and slowly gains a deeper understanding of her character. They fall into a warm rhythm as they explore their shared passion for music and find solace in each other's company. However, a mysterious figure attempts to separate them by stealing Lily's memories and trying to manipulate her emotions. Michael must fight back against this villain and help Lily regain her memories while keeping their love alive.
#
# **Possible Themes:**
#
# * Memory, identity, loss, finding yourself, the power of music to connect people, love conquering obstacles, overcoming grief.
#
# **Potential Story Arcs:**
# ------------------------------------------------------------
#
# 📝 Plot 4: A heist movie where the thieves steal abstract concepts instead of objects
# Plot Outline: ## Heist: Abstract Concepts
#
# **Logline:** A group of friends decides to heist an important concept from their wealthy, unethical boss. They work together to figure out how to steal it, and in the process, they learn that some things are just too valuable to be stolen.
#
# **Characters:**
# * **The Thieves:**
#     * **Liam**: The leader who comes up with the plan. He's a gifted artist who can understand abstract concepts better than anyone else.
#     * **Maya**: Liam's best friend. She is intelligent but more reckless than Liam.
#     ruptedException: Error during request processing
#     * **Carlos**: The calm but secretly greedy one. He is very good at finding loopholes and weaknesses in any system.
#
# * **The Boss:** An evil entrepreneur who wants to hold onto his control over everyone in his city.
#
# **Plot Outline:**
#
# 1. **Idea Stage:** Liam feels like he's not getting paid enough so he talks to the other friends about it. Maya argues against him while Carlos agrees with her idea of stealing something valuable.
#
# 2. **Planning Stage:** Liam discovers that they can use a special program to make a copy of the boss's important concept and then sell it for double the price back to the boss. Liam believes this will solve their problems since they'll have more money.
#
# 3. **Action Stage:** The thieves gather supplies and create a plan to execute their heist without being caught. All three go into action, except Maya who realizes she doesn't care if it all goes wrong as long as she gets what she wants. Everything goes well until they realize that the concept is impossible to steal because someone has taken over the system.
#
# 4. **Resolution Stage:** Liam tries to get the stolen concept back, but he fails. His friends don't want to lose anything and come back to the boss to get even - no matter the cost. However, the concept
# ------------------------------------------------------------
#
# 📝 Plot 5: A coming-of-age story in a generation ship traveling to another star
# Plot Outline: ## Generation Ship Story Outline: "The Legacy"
#
# **Genre:** Science Fiction, Adventure, Family Drama
#
# **Characters:**
# * **Maya:** The main protagonist. She is 18 years old and learns that her great-grandmother died on the ship years ago.
# * **Max:** Maya's best friend who also lives on the ship. He is always there to cheer her up and help her with any problems she may be experiencing.
# * **Grandpa John:** Max's grandfather who is the captain of the ship. He has been teaching the children about navigating the vast galaxy.
# ------------------------------------------------------------

# %%
story_beginnings = [
    "She found the letter under her pillow, written in her own handwriting, but she had no memory of writing it.",
    "The museum was supposed to be closed, but all the lights were on and there was music playing inside.",
    "Every morning at exactly 7:23 AM, the same stranger waved at him from the train platform.",
    "The antique shop appeared overnight, and its owner claimed to sell memories instead of objects.",
    "When she opened her laptop, there was a message from herself: 'Don't trust anyone, including me.'"
]

print("\n🔄 STORY CONTINUATION:")
for i, beginning in enumerate(story_beginnings, 1):
    print(f"\n📖 Beginning {i}: {beginning}")
    continuation = generate_creative_content(beginning, "continue", 350)
    print(f"Story Continuation: {continuation}")
    print("-" * 60)
# Out:
# 🔄 STORY CONTINUATION:
#
# 📖 Beginning 1: She found the letter under her pillow, written in her own handwriting, but she had no memory of writing it.
# Story Continuation: She was confused and worried so she decided to take a look at when the letter was written. It turned out the date on the paper was from two days ago.
#
# She looked around and saw that there were only flowers left in the vase from yesterday. They didn't smell like anything bad, but they still made her think.
#
# Suddenly, she remembered something. When she had been feeling sleepy and tired, she had seen a few letters lying in the living room. So she picked them up and took a closer look. The script was all over the place, making her even more confused.
#
# But then she noticed one thing. Somehow the letters had been folded into each other. She carefully unfolded them and realized how much work it must have taken for her to write such messy lines. She now knew where she had found the letter and why it smelled so sweet.
# ------------------------------------------------------------
#
# 📖 Beginning 2: The museum was supposed to be closed, but all the lights were on and there was music playing inside.
# Story Continuation: The kids in the museum were very excited. They wanted to see what was happening inside so they snuck in through a big window.
#
# Down the hallway, they saw lots of people and heard them talking. One of the kids asked one of the strangers to explain why everyone was here.
#
# "We are here because we have a special surprise," said one stranger. "A famous toy is coming! It's going to stay here at the museum until it goes on its tour around the world!"
#
# The kids gasped in amazement. They had never seen something like that before! They wished they could go on the tour, but they knew it wouldn't be possible.
#
# As the crowd grew bigger, more and more strange things started to happen. One by one, the toys came alive and danced for everyone to enjoy. The museum felt like it was in two different worlds: normal and magical.
#
# Just as soon as the sun began to rise, the magic disappeared. People started to wake up and leave the museum, never looking back again. The only thing left behind was a memory of the amazing day.
# ------------------------------------------------------------
#
# 📖 Beginning 3: Every morning at exactly 7:23 AM, the same stranger waved at him from the train platform.
# Story Continuation: The children were curious and had never seen anyone so early in the morning, but the stranger always smiled.
#
# One day, a little girl saw the stranger waving at her as she was walking to school. They both had smiles on their faces and nodded hello. The stranger waved again and left for work.
#
# Then, one day, the same old stranger was there again, waiting at the platform. The child saw him and began to run over, but he was slow and clumsy. He tripped with his big feet, fell down and bumped into the stranger's leg.
#
# Both of them looked up, then laughed. The stranger helped the girl up, and they exchanged words. When it was time for the stranger to go home, he gave the girl a small gift. It was an orange! The girl was so excited; she couldn't wait to eat it. After that, every day, the girl would look forward to seeing the stranger wave at her from the train platform. She knew he was always there for her.
# ------------------------------------------------------------
#
# 📖 Beginning 4: The antique shop appeared overnight, and its owner claimed to sell memories instead of objects.
# Story Continuation: Lots of people went into the shop and were amazed by the variety of old items inside. After a while, everyone was eager to buy one for themselves.
#
# One day, a little girl named Lily went into the antique shop with her mom. Inside the shop, there were many interesting items to see but none that caught their eye. Lily wanted to try something to make her dream come true. She asked the owner if she could purchase a memory. The owner smiled and said yes, so Lily and her mom bought a special wooden box filled with many different small pieces of wood.
#
# As they left the antique shop, Lily noticed something strange about the way the wooden box felt in her hands. It seemed heavy and warm. When she opened it up, she found out what made it feel different. There was a beautiful picture embedded within. Lily was overjoyed and kept the wooden box close to her heart, as it held her new memory.
# ------------------------------------------------------------
#
# 📖 Beginning 5: When she opened her laptop, there was a message from herself: 'Don't trust anyone, including me.'
# Story Continuation: She was confused. She had just finished writing the message to another user of the same laptop. It said that not everyone can be trusted, not even when it is you. She looked around and saw nothing unusual. Maybe the laptop itself could have been sending messages like this before.
#
# The user continued to use it for a few months, and kept receiving similar messages. They didn't make sense, but they were persistent. One day, she tried copying the message into another program, then pasting it back in. However, it always remained as a blank piece of text. Nothing seemed to work. After some time, she decided to delete the entire conversation, hoping it would all go away. But it seemed too late. The content was already stored on the laptop, ready for her next use.
# ------------------------------------------------------------

# %%
poetry_themes = [
    "The feeling of watching sunrise from space",
    "A conversation between the ocean and the moon",
    "The last tree in a concrete world",
    "Digital love in an analog heart",
    "The sound of silence in a busy city"
]

print("\n🎭 POETRY GENERATION:")
for i, theme in enumerate(poetry_themes, 1):
    print(f"\n🌟 Theme {i}: {theme}")
    poem = generate_creative_content(theme, "poem", 200)
    print(f"Generated Poem: {poem}")
    print("-" * 60)
# Out:
# 🎭 POETRY GENERATION:
#
# 🌟 Theme 1: The feeling of watching sunrise from space
# Generated Poem: I was in the air, floating around in a big white suit. I saw a bright light in the sky and it gave me chills. Then, I started to feel my heart beating fast.
#
# Suddenly, I realized what was happening! I was witnessing the beginning of a new day. The morning sun had risen above the horizon, making everything bright and beautiful. It was truly special to be here and experience such a magical moment.
#
# As I looked out at this wondrous sight, I couldn't help but smile. I felt happy and peaceful all over. It was an amazing feeling. From that moment on, I knew that I wanted to explore more of the world and see even more of its wonders.
# ------------------------------------------------------------
#
# 🌟 Theme 2: A conversation between the ocean and the moon
# Generated Poem: The ocean whispered, "It's so calm here tonight."
#
# The moon smiled and replied, "I can see your waves from up above."
#
# "Oh, it's so peaceful," the ocean said. "You know you make me look beautiful."
#
# The moon chuckled, "Only if I was the one doing the talking."
#
# They talked for hours, until the sun started to rise.
#
# Then they both whispered goodbye and waved at each other.
# ------------------------------------------------------------
#
# 🌟 Theme 3: The last tree in a concrete world
# Generated Poem: One day, the city was very busy making buildings. All around there were many things such as cars and trucks.
#
# Suddenly, the sky began to change color. Everything was bright red and orange. People looked up at the sky and said "Wow! So bright!" But no one thought it could be interesting or funny.
#
# One man saw that a big bird had landed on his rooftop. He walked outside and watched the bird closely while the other people continued to make their way through the building maze. As he watched the bird fly away, he smiled. It didn't seem like anything unusual but he found it kind of funny.
#
# That night the man decided to write down his thoughts about the bird and the orange sky. He wrote these words:
#
# "The orange sky is so pretty! I wonder if the birds make all the colors when they fly?"
#
# From then on, whenever the man looked up at the sky, he would think about the funny story the
# ------------------------------------------------------------
#
# 🌟 Theme 4: Digital love in an analog heart
# Generated Poem: She loved him, but she was sad.
# He told her he would never let her go.
# She didn't know what to say,
# But that wasn't the reason why she couldn't feel the way.
#
# All around them was technology so bright and fast.
# He showed her a world where they were always connected by data cast.
# She felt the pull of this digital connection so strong.
# But her heart just wanted him to be there and not belong.
#
# They talked for hours on end, their voices filling up the air.
# He made sure she could hear his voice through all the digital flare.
# But still in the end, she knew it was just beyond reach.
# A digital connection in an analog heart, too far to breach.
# ------------------------------------------------------------
#
# 🌟 Theme 5: The sound of silence in a busy city
# Generated Poem: The streets were loud, but it was too much for me.
# I needed to find somewhere quiet, so I went on my way.
#
# At last I found a park with a big tree, just the right place!
# It had tall trees that made the sky seem so spacious.
#
# The birds were singing and the leaves were softly falling, while I was there.
# In this quiet spot, not one sound or even a glare.
# "Hey," someone called out from inside the store, "the lights are gone!"
# But no matter what I saw, I felt calm and serene all alone.
#
# So if you need some peace, even though everything is moving fast,
# a little quiet can be found when the world goes past!
# ------------------------------------------------------------
